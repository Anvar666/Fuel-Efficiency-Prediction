# %% [markdown]
# # FUEL EFFICIENCY PREDICTION

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np                                   # To import numpy

# %%
import pandas as pd                                   # To import pandas as pd

# %%
import matplotlib.pyplot as plt                       # To import matplotlib as plt

# %%
import seaborn as sns                                 # To import seaborn as sns

# %% [markdown]
# # Description of each column

# %% [markdown]
# mpg: Miles per gallon, representing the fuel efficiency of the car in terms of how many miles it can travel per gallon of fuel consumed. Higher values indicate better fuel efficiency.
#
# cylinders: The number of cylinders in the engine. This typically ranges from 3 to 12 cylinders, with more cylinders generally indicating a more powerful engine.
#
# displacement: The total volume of all cylinders in the engine in cubic inches or liters. It represents the engine's capacity, with larger values generally indicating more powerful engines.
#
# horsepower: The power output of the engine, usually measured in horsepower. Higher horsepower values generally indicate higher engine performance.
#
# weight: The weight of the car, typically measured in pounds or kilograms. Heavier cars tend to consume more fuel.
#
# acceleration: The time it takes for the car to accelerate from 0 to 60 miles per hour (or 0 to 100 kilometers per hour), usually measured in seconds. Lower values indicate quicker acceleration.
#
# model year: The year when the car model was manufactured. It can be used to track improvements in fuel efficiency and technological advancements over time.
#
# origin: The country of origin or manufacture of the car. This could be represented numerically or categorically, with values such as 1 for American, 2 for European, and 3 for Asian, for example.
#
# car name: The name or identifier of the car model.

# %% [markdown]
# # Importing Dataset

# %%
a=pd.read_csv("auto-mpg.csv")                        # To load data
a
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
a.head(400)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Analysing

# %%
a.info()                                                           # To get information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
a.isnull().sum()                                                       # To check if there are any null values.
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# # maximum

# %%
a["mpg"].max()
# Out:
# 46.6

# %%
a["displacement"].max()
# Out:
# 455.0

# %%
a["weight"].max()
# Out:
# 5140

# %%
a["acceleration"].max()
# Out:
# 24.8

# %% [markdown]
# # minimum

# %%
a["mpg"].min()
# Out:
# 9.0

# %%
a["displacement"].min()
# Out:
# 68.0

# %%
a["weight"].min()
# Out:
# 1613

# %%
a["acceleration"].min()
# Out:
# 8.0

# %%
a.describe()                                                     # To describe set(like max,min,mean,count.....)
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
a.shape                                                               # To find number of rows and columns.
# Out:
# (398, 9)

# %%
a.count()                                                             #To count the number of each columns and rows
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model year      398
# origin          398
# car name        398
# dtype: int64

# %% [markdown]
# # Visualizing

# %%
sns.scatterplot(x="mpg",y="cylinders",hue="mpg",palette="Set2",data=a)                        
plt.show()

# %%
sns.scatterplot(x="mpg",y="cylinders",hue="horsepower",palette="Set2",data=a)               
plt.show()

# %%
sns.scatterplot(x="mpg",y="acceleration",hue="horsepower",palette="Set2",data=a)               
plt.show()

# %%
sns.scatterplot(x="mpg",y="model year",hue="horsepower",palette="Set2",data=a)               
plt.show()

# %%
sns.scatterplot(x="mpg",y="weight",hue="mpg",palette="Set2",data=a)               
plt.show()

# %%
sns.scatterplot(x="mpg",y="origin",hue="car name",palette="Set2",data=a)    
plt.legend(loc="best",bbox_to_anchor=(1, 1))
plt.show()

# %%
sns.scatterplot(x="mpg",y="displacement",hue="mpg",palette="Set2",data=a)                        
plt.show()

# %%
sns.lineplot(x="mpg",y="displacement",data=a)                        
plt.show()

# %%
sns.lineplot(x="mpg",y="acceleration",data=a)                        
plt.show()

# %%
sns.lineplot(x="mpg",y="weight",data=a)                        
plt.show()

# %%
sns.lineplot(x="mpg",y="model year",data=a)                        
plt.show()

# %%
import warnings                                      # To remove warning
warnings.filterwarnings("ignore")

# %%
sns.heatmap(a.corr(),cbar=True,linewidth=0.5)        #heatmap of the dataset 'a'
plt.show()

# %%
sns.pairplot(hue="mpg",palette="Set1",data=a)              #pairplot of fuel efficiency in data 'a'
plt.show()

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
d=LabelEncoder()
a["horsepower"]=d.fit_transform(a["horsepower"])                         # To convert string into numbers
a
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0          15    3504          12.0
# 1    15.0          8         350.0          33    3693          11.5
# 2    18.0          8         318.0          27    3436          11.0
# 3    16.0          8         304.0          27    3433          12.0
# 4    17.0          8         302.0          22    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          80    2790          15.6
# 394  44.0          4          97.0          51    2130          24.6
# 395  32.0          4         135.0          78    2295          11.6
# 396  28.0          4         120.0          73    2625          18.6
# 397  31.0          4         119.0          76    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Prediction - Regression

# %%
x=a.iloc[:,[1,2,3,4,5,6,7]].values                                   # Independent values
x
# Out:
# array([[  8. , 307. ,  15. , ...,  12. ,  70. ,   1. ],
#        [  8. , 350. ,  33. , ...,  11.5,  70. ,   1. ],
#        [  8. , 318. ,  27. , ...,  11. ,  70. ,   1. ],
#        ...,
#        [  4. , 135. ,  78. , ...,  11.6,  82. ,   1. ],
#        [  4. , 120. ,  73. , ...,  18.6,  82. ,   1. ],
#        [  4. , 119. ,  76. , ...,  19.4,  82. ,   1. ]])

# %%
y=a.iloc[:,0].values                                          # Dependent value
y
# Out:
# array([18. , 15. , 18. , 16. , 17. , 15. , 14. , 14. , 14. , 15. , 15. ,
#        14. , 15. , 14. , 24. , 22. , 18. , 21. , 27. , 26. , 25. , 24. ,
#        25. , 26. , 21. , 10. , 10. , 11. ,  9. , 27. , 28. , 25. , 25. ,
#        19. , 16. , 17. , 19. , 18. , 14. , 14. , 14. , 14. , 12. , 13. ,
#        13. , 18. , 22. , 19. , 18. , 23. , 28. , 30. , 30. , 31. , 35. ,
#        27. , 26. , 24. , 25. , 23. , 20. , 21. , 13. , 14. , 15. , 14. ,
#        17. , 11. , 13. , 12. , 13. , 19. , 15. , 13. , 13. , 14. , 18. ,
#        22. , 21. , 26. , 22. , 28. , 23. , 28. , 27. , 13. , 14. , 13. ,
#        14. , 15. , 12. , 13. , 13. , 14. , 13. , 12. , 13. , 18. , 16. ,
#        18. , 18. , 23. , 26. , 11. , 12. , 13. , 12. , 18. , 20. , 21. ,
#        22. , 18. , 19. , 21. , 26. , 15. , 16. , 29. , 24. , 20. , 19. ,
#        15. , 24. , 20. , 11. , 20. , 21. , 19. , 15. , 31. , 26. , 32. ,
#        25. , 16. , 16. , 18. , 16. , 13. , 14. , 14. , 14. , 29. , 26. ,
# ...

# %% [markdown]
# # Train, Test Splitting

# %%
from sklearn.model_selection import train_test_split                       
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=80,random_state=35)

# %%
x_train
# Out:
# array([[  6. , 250. ,   6. , ...,  16.4,  77. ,   1. ],
#        [  6. , 225. ,   3. , ...,  16.5,  73. ,   1. ],
#        [  4. , 119. ,  91. , ...,  14.7,  78. ,   3. ],
#        ...,
#        [  6. , 232. ,   0. , ...,  13. ,  71. ,   1. ],
#        [  4. , 156. ,   3. , ...,  16.7,  78. ,   1. ],
#        [  6. , 250. ,   6. , ...,  16.2,  76. ,   1. ]])

# %%
x_test
# Out:
# array([[6.000e+00, 2.500e+02, 3.000e+00, 3.459e+03, 1.600e+01, 7.500e+01,
#         1.000e+00],
#        [4.000e+00, 9.800e+01, 6.300e+01, 2.155e+03, 1.650e+01, 7.800e+01,
#         1.000e+00],
#        [4.000e+00, 1.200e+02, 6.800e+01, 2.635e+03, 1.830e+01, 8.100e+01,
#         3.000e+00],
#        [6.000e+00, 2.310e+02, 6.000e+00, 3.415e+03, 1.580e+01, 8.100e+01,
#         1.000e+00],
#        [4.000e+00, 1.200e+02, 9.100e+01, 2.506e+03, 1.450e+01, 7.200e+01,
#         3.000e+00],
#        [8.000e+00, 3.500e+02, 3.200e+01, 4.456e+03, 1.350e+01, 7.200e+01,
#         1.000e+00],
#        [4.000e+00, 1.220e+02, 8.000e+01, 2.226e+03, 1.650e+01, 7.200e+01,
#         1.000e+00],
#        [8.000e+00, 3.510e+02, 3.100e+01, 4.363e+03, 1.300e+01, 7.300e+01,
#         1.000e+00],
#        [6.000e+00, 2.000e+02, 7.900e+01, 2.587e+03, 1.600e+01, 7.000e+01,
#         1.000e+00],
#        [8.000e+00, 3.500e+02, 2.400e+01, 4.055e+03, 1.200e+01, 7.600e+01,
#         1.000e+00],
# ...

# %%
y_train
# Out:
# array([17.5, 18. , 27.2, 15. , 32.2, 21.5, 31. , 19.8, 26. , 25. , 20.5,
#        28. , 25. , 19. , 22.5, 15. , 36. , 36.1, 31. , 27.4, 12. , 20. ,
#        11. , 12. , 14. , 26. , 36. , 33.8, 25.4, 16.5, 36. , 46.6, 29.5,
#        39.4, 29. , 24.3, 18.2, 28. , 34.4, 16. , 17. , 14. , 34.1, 15. ,
#        27. , 20.5, 16. , 35.1, 28. , 12. , 13. , 33. , 27. , 33.7, 29.8,
#        32. , 11. , 41.5, 16. , 29. , 39.1, 37. , 13. , 31.5, 18.6, 13. ,
#        15. , 38.1, 29. , 34.7, 15. , 15. , 30.9, 30. , 25.4, 38. , 18. ,
#        17. , 37.3, 21. , 26. , 23.7, 22. , 43.1, 13. , 23. , 17.5, 32.1,
#        20. , 21. , 25. , 29. , 14. , 13. , 21. , 43.4, 24.5, 28. , 28.8,
#        32.7, 22. , 32.4, 29.5, 24. , 14. , 27.2, 27. , 20. , 40.9, 19. ,
#        17.7, 11. , 24. , 23.9, 19.2, 23.5, 20.8, 22. , 33.5, 16. , 34.3,
#        39. , 15. , 21.1, 24. , 21. , 16.2, 16.9, 22. , 34.1, 23. , 16. ,
#        14. , 23.8, 22. , 23.6, 31. , 23. , 13. , 36.1, 32.8, 19. , 29. ,
# ...

# %%
y_test
# Out:
# array([18. , 30. , 31.6, 22.4, 23. , 12. , 21. , 13. , 21. , 13. ,  9. ,
#        15. , 20.2, 34.5, 19. , 16.5, 24. , 16. , 28. , 25.8, 24. , 15. ,
#        20.3, 13. , 13. , 18.5, 30. , 26. , 28.1, 22. , 26. , 30. , 21. ,
#        38. , 20.6, 18. , 34. , 18. , 23. , 37.7, 32. , 13. , 26.6, 44. ,
#        19. , 28. , 23. , 34.2, 14. , 24.2, 29. , 33. , 26. , 22. , 20.2,
#        15.5, 13. , 15. , 13. , 26.4, 15. , 19.4, 26.8, 10. , 14. , 26.6,
#        26. , 33.5, 37. , 19. , 14. , 16. , 36.4, 30.5, 15.5, 18. , 13. ,
#        19. , 22. , 11. ])

# %% [markdown]
# # Linear

# %%
from sklearn.linear_model import LinearRegression                        # Importing Linear Regression

# %%
regressor=LinearRegression()
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(x_train,y_train)                                          # Fitting on Regressor
# Out:
# LinearRegression()

# %%
xpred1=regressor.predict(x_train)
xpred1
# Out:
# array([20.04671486, 19.52401359, 30.92977487, 19.14452518, 32.36045663,
#        25.84663185, 35.89985947, 25.36646738, 23.29149011, 26.03323669,
#        20.447967  , 26.35034688, 23.16797126, 25.49716185, 22.9413923 ,
#        14.64397937, 30.91084706, 33.95618012, 29.3675036 , 26.42262625,
#        11.09460056, 22.56142025,  8.36107341,  9.46470441, 10.93854038,
#        25.59193648, 31.79176083, 33.263296  , 22.7232932 , 19.4668703 ,
#        32.38963617, 33.31044677, 30.81851164, 32.19904189, 29.20041998,
#        25.82716438, 20.01106644, 29.31780896, 32.072327  , 15.69574942,
#        15.40965244, 11.61924442, 33.27916247, 12.4751142 , 28.2163593 ,
#        21.06506645, 15.99519654, 36.29735089, 26.03735008,  8.93497295,
#        10.76885959, 32.56819585, 29.06256333, 33.41315409, 33.75886627,
#        35.74290559,  9.32440749, 31.79015698, 12.18343638, 31.00715801,
#        36.37013354, 35.1669097 , 10.36239397, 31.24930904, 19.88408694,
# ...

# %%
ypred1=regressor.predict(x_test)
ypred1
# Out:
# array([18.92878768, 29.08552979, 30.91400835, 23.43087119, 24.9451156 ,
#        10.71307344, 24.62060497, 12.0947041 , 21.34404492, 16.39897217,
#         7.00894708, 18.31787782, 23.9380418 , 31.59751394, 17.70116414,
#        14.16254652, 22.87068348, 13.30885664, 27.83430011, 28.89758502,
#        26.81675319, 13.9113038 , 25.20470468, 10.16554686,  8.55945203,
#        19.76313527, 25.17579473, 27.14182269, 25.95329994, 23.84200453,
#        26.1524777 , 32.02439417, 20.83074592, 35.57393159, 21.41533351,
#        16.70370793, 30.87351479, 17.18097378, 21.34139199, 34.45866979,
#        29.62263654, 11.89575796, 23.03317053, 34.17138124, 21.90777651,
#        30.10326723, 23.67318811, 29.31787363, 14.66193182, 27.8949095 ,
#        28.36890158, 31.82998978, 26.78065577, 22.9791963 , 26.27331866,
#        16.3846553 , 18.271372  , 21.99805663, 11.26063479, 26.40037629,
#        15.91880255, 19.79185214, 25.91569288,  8.3786072 , 12.14616167,
# ...

# %%
trainingscore1=regressor.score(x_train,y_train)
trainingscore1
# Out:
# 0.8115444828775101

# %%
testingscore1=regressor.score(x_test,y_test)
testingscore1
# Out:
# 0.8526360162258647

# %%
from sklearn import metrics

# %%
print("mae"),metrics.mean_absolute_error(y_test,ypred1)
# Out:
# mae
# (None, 2.2511803250137343)

# %%
print("mse"),metrics.mean_squared_error(y_test,ypred1)
# Out:
# mse
# (None, 8.838979244137999)

# %%
print("rmse"),np.sqrt(metrics.mean_squared_error(y_test,ypred1))
# Out:
# rmse
# (None, 2.973042085833633)

# %%
print("rmae"),np.sqrt(metrics.mean_absolute_error(y_test,ypred1))
# Out:
# rmae
# (None, 1.5003933900859916)

# %%
from sklearn.metrics import r2_score

# %%
r1=r2_score(y_test,ypred1)
r1
# Out:
# 0.8526360162258647

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR                                               # Importing SVR

# %%
svr=SVR(kernel="linear")
svr.fit(x_train,y_train)                                                  # Fitting on SVR
# Out:
# SVR(kernel='linear')

# %%
xpred2=svr.predict(x_train)
xpred2

# %%
ypred2=svr.predict(x_test)
ypred2
# Out:
# array([21.12395014, 29.79744484, 29.96221502, 20.56426493, 29.04491384,
#         9.14500048, 29.49487676,  9.60874764, 22.69510781, 11.38784959,
#         7.59975239, 14.41984035, 19.39238165, 28.55836746, 19.115179  ,
#         8.87822225, 20.45645212,  9.6787684 , 26.94369026, 26.68402498,
#        31.04830012, 11.45600051, 26.4665484 ,  7.84347389,  8.006556  ,
#        12.45268005, 26.85270048, 29.86570718, 25.94412814, 29.7016837 ,
#        29.2349783 , 33.27503116, 21.79238319, 32.83993962, 20.99627866,
#        19.72336247, 28.2378639 , 16.12650031, 20.1712253 , 33.00041514,
#        33.93452295,  9.79803182, 16.23176183, 33.91663502, 24.34736805,
#        31.97153526, 28.80318615, 28.57130426, 12.63072103, 23.12665062,
#        33.64022725, 35.10387872, 30.00311172, 30.0740593 , 19.57377985,
#        10.06369724, 12.99070378, 21.67764613, 10.12660883, 26.02546306,
#        14.47423971, 12.99595887, 22.71751798,  8.15333442, 11.22041532,
# ...

# %%
trainingscore2=svr.score(x_train,y_train)
trainingscore2
# Out:
# 0.6015041612275231

# %%
testingscore2=svr.score(x_test,y_test)
testingscore2
# Out:
# 0.6371202028608154

# %%
print("mse"),metrics.mean_squared_error(y_test,ypred2)
# Out:
# mse
# (None, 21.765745692287847)

# %%
print("mae"),metrics.mean_absolute_error(y_test,ypred2)
# Out:
# mae
# (None, 3.776565622088904)

# %%
print("rmse"),metrics.mean_squared_error(y_test,ypred2)
# Out:
# rmse
# (None, 21.765745692287847)

# %%
print("rmae"),np.sqrt(metrics.mean_absolute_error(y_test,ypred2))
# Out:
# rmae
# (None, 1.943338782119295)

# %%
r2=r2_score(y_test,ypred2)
r2
# Out:
# 0.6371202028608154

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor                        # Importing Decision Tree

# %%
dtr=DecisionTreeRegressor()
dtr
# Out:
# DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)                                              # Fitting on Decision Tree Regressor
# Out:
# DecisionTreeRegressor()

# %%
xpred3=dtr.predict(x_train)
xpred3
# Out:
# array([17.5, 18. , 27.2, 15. , 32.2, 21.5, 31. , 19.8, 26. , 25. , 20.5,
#        28. , 25. , 19. , 22.5, 15. , 36. , 36.1, 31. , 27.4, 12. , 20. ,
#        11. , 12. , 14. , 26. , 36. , 33.8, 25.4, 16.5, 36. , 46.6, 29.5,
#        39.4, 29. , 24.3, 18.2, 28. , 34.4, 16. , 17. , 14. , 34.1, 15. ,
#        27. , 20.5, 16. , 35.1, 28. , 12. , 13. , 33. , 27. , 33.7, 29.8,
#        32. , 11. , 41.5, 16. , 29. , 39.1, 37. , 13. , 31.5, 18.6, 13. ,
#        15. , 38.1, 29. , 34.7, 15. , 15. , 30.9, 30. , 25.4, 38. , 18. ,
#        17. , 37.3, 21. , 26. , 23.7, 22. , 43.1, 13. , 23. , 17.5, 32.1,
#        20. , 21. , 25. , 29. , 14. , 13. , 21. , 43.4, 24.5, 28. , 28.8,
#        32.7, 22. , 32.4, 29.5, 24. , 14. , 27.2, 27. , 20. , 40.9, 19. ,
#        17.7, 11. , 24. , 23.9, 19.2, 23.5, 20.8, 22. , 33.5, 16. , 34.3,
#        39. , 15. , 21.1, 24. , 21. , 16.2, 16.9, 22. , 34.1, 23. , 16. ,
#        14. , 23.8, 22. , 23.6, 31. , 23. , 13. , 36.1, 32.8, 19. , 29. ,
# ...

# %%
ypred3=dtr.predict(x_test)
ypred3
# Out:
# array([20. , 34.4, 31.3, 17.6, 24. , 14. , 28. , 13. , 24.5, 15.5, 14. ,
#        18. , 21.5, 27.2, 18. , 15.5, 23.8, 13. , 28.4, 26. , 27. , 15. ,
#        21.6, 13. , 13. , 16.5, 25.4, 22. , 25.4, 25. , 28. , 31.5, 24.5,
#        32.3, 16.2, 19. , 27. , 17. , 20. , 29.8, 31. , 14. , 23. , 38.1,
#        20. , 29. , 28. , 30.9, 18. , 25.4, 30. , 31. , 25. , 21. , 19.8,
#        16. , 13. , 15. , 16. , 24.3, 18. , 18.2, 30. , 13. , 15. , 28.4,
#        25. , 30.5, 35. , 19.4, 17. , 13. , 25.4, 29. , 15. , 20. , 15. ,
#        22. , 26. , 13. ])

# %%
trainingscore3=dtr.score(x_train,y_train)
trainingscore3
# Out:
# 1.0

# %%
testingscore3=dtr.score(x_test,y_test)
testingscore3
# Out:
# 0.8264834615779374

# %%
print("mae"),metrics.mean_absolute_error(y_test,ypred3)
# Out:
# mae
# (None, 2.46375)

# %%
print("mse"),metrics.mean_squared_error(y_test,ypred3)
# Out:
# mse
# (None, 10.407625000000001)

# %%
print("rmse"),np.sqrt(metrics.mean_squared_error(y_test,ypred3))
# Out:
# rmse
# (None, 3.2260850887724586)

# %%
print("rmae"),np.sqrt(metrics.mean_absolute_error(y_test,ypred3))
# Out:
# rmae
# (None, 1.5696337152342263)

# %%
r3=r2_score(y_test,ypred3)
r3
# Out:
# 0.8264834615779374

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor               # Importing Random Forest

# %%
RFR=RandomForestRegressor()
RFR
# Out:
# RandomForestRegressor()

# %%
RFR.fit(x_train,y_train)                                         # Fitting on Random Forest Regressor
# Out:
# RandomForestRegressor()

# %%
xpred4=RFR.predict(x_train)
xpred4
# Out:
# array([18.024, 18.017, 27.617, 16.658, 32.707, 21.657, 32.665, 20.927,
#        25.514, 25.4  , 20.25 , 26.56 , 24.66 , 20.448, 21.541, 15.18 ,
#        34.193, 35.7  , 29.915, 28.608, 12.21 , 20.024, 11.7  , 12.15 ,
#        13.65 , 26.68 , 33.361, 36.176, 23.384, 16.684, 35.457, 42.661,
#        29.001, 37.402, 27.93 , 24.546, 17.853, 28.47 , 34.567, 16.453,
#        16.12 , 13.925, 34.545, 14.64 , 26.701, 20.209, 15.921, 36.06 ,
#        27.4  , 12.11 , 12.79 , 31.77 , 27.247, 34.06 , 32.456, 33.509,
#        11.47 , 39.227, 15.519, 29.713, 38.455, 36.522, 13.17 , 32.39 ,
#        18.745, 13.16 , 15.095, 36.957, 29.09 , 34.902, 15.491, 14.94 ,
#        30.418, 29.576, 25.748, 31.775, 17.35 , 17.663, 36.217, 20.759,
#        27.59 , 26.92 , 24.115, 39.558, 13.16 , 23.547, 16.765, 33.21 ,
#        19.721, 20.425, 24.675, 28.965, 13.97 , 14.885, 21.235, 40.271,
#        24.785, 27.78 , 27.503, 28.904, 21.743, 32.843, 31.172, 23.82 ,
# ...

# %%
ypred4=RFR.predict(x_test)
ypred4
# Out:
# array([17.198, 31.979, 30.789, 21.185, 22.758, 13.44 , 26.848, 13.545,
#        20.588, 15.4  , 11.99 , 17.103, 20.218, 32.888, 18.067, 14.547,
#        20.901, 13.69 , 28.281, 27.25 , 26.315, 14.87 , 22.892, 12.89 ,
#        13.08 , 15.787, 26.665, 24.759, 27.014, 23.278, 26.33 , 31.184,
#        20.398, 34.547, 20.086, 17.193, 29.83 , 15.167, 19.949, 35.129,
#        31.075, 13.985, 21.512, 40.836, 19.589, 27.995, 26.799, 36.071,
#        16.695, 27.261, 27.59 , 31.23 , 25.939, 22.125, 23.058, 15.92 ,
#        14.72 , 17.922, 14.36 , 24.736, 16.685, 17.549, 26.222, 12.28 ,
#        14.27 , 28.323, 26.985, 30.221, 31.493, 19.562, 16.001, 15.465,
#        26.698, 28.877, 16.158, 18.481, 14.56 , 20.674, 23.826, 13.02 ])

# %%
trainingscore4=RFR.score(x_train,y_train)
trainingscore4
# Out:
# 0.9808950807006831

# %%
testingscore4=RFR.score(x_test,y_test)
testingscore4
# Out:
# 0.9058398363220606

# %%
print("mse"),metrics.mean_squared_error(y_test,ypred4)
# Out:
# mse
# (None, 5.64778252499999)

# %%
print("mae"),metrics.mean_absolute_error(y_test,ypred4)
# Out:
# mae
# (None, 1.8016249999999991)

# %%
print("rmse"),np.sqrt(metrics.mean_squared_error(y_test,ypred4))
# Out:
# rmse
# (None, 2.376506369652728)

# %%
print("rmae"),np.sqrt(metrics.mean_absolute_error(y_test,ypred4))
# Out:
# rmae
# (None, 1.342246251624492)

# %%
r4=r2_score(y_test,ypred4)
r4
# Out:
# 0.9058398363220606

# %%
z=pd.DataFrame({"ML Models":["Linear","SVR","Decision Tree","Random Forest"],
               "Accuracy Score":[testingscore1,testingscore2,testingscore3,testingscore4]})
z
# Out:
#        ML Models  Accuracy Score
# 0         Linear        0.852636
# 1            SVR        0.637120
# 2  Decision Tree        0.826483
# 3  Random Forest        0.905840

# %%
sns.barplot(x="ML Models",y="Accuracy Score",data=z)        
z.sort_values(by="Accuracy Score",ascending=False)
# Out:
#        ML Models  Accuracy Score
# 3  Random Forest        0.905840
# 0         Linear        0.852636
# 2  Decision Tree        0.826483
# 1            SVR        0.637120

# %% [markdown]
# # Test Data's Accuracy Of All Models

# %% [markdown]
# Test data accuracy in Linear regression - 85% Test data accuracy in SVR - 63% Test data accuracy in Decision Tree - 82% Test data accuracy in Random Forest - 90%

# %% [markdown]
# HENCE BEST MODELS TO PREDICT Fuel Efficiency Range FROM THE GIVEN DATASET ARE RANDOM FOREST MODEL

# %% [markdown]
# # Input Method

# %%
cylinders=int(input("Enter cylinders :"))
displacement=int(input("Enter displacement :"))
horsepower=int(input("Enter horsepower :"))
weight=int(input("Enter weight: "))
acceleration=int(input("Enter acceleration: "))
model_year=int(input("Enter model year: "))
origin=int(input("Enter origin: "))
New=[cylinders,displacement,horsepower,weight,acceleration,model_year,origin] 
import numpy as np                            # creating a variable including all the above input variables
numpy=np.asarray(New)                                           # converting into numpy array
Newarray=numpy.reshape(1,-1)
pred=regressor.predict(Newarray)
d=int(pred)
print("mpg",d)
# Out:
# Enter cylinders :8
# Enter displacement :307
# Enter horsepower :15
# Enter weight: 3504
# Enter acceleration: 12
# Enter model year: 70
# Enter origin: 1
# mpg 15
